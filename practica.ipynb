# %%
### Importaciones ###

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
### URL con los datos ###

url = 'https://data.cityofnewyork.us/api/views/6fi9-q3ta/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url)

# %%
### Dividiendo en campos mas significativos ###

df['hour_beginning'] = pd.to_datetime(df['hour_beginning'])
df['hour'] = df['hour_beginning'].dt.hour
df['month'] = df['hour_beginning'].dt.month
df['date'] = df['hour_beginning'].dt.date
df['day_name'] = df['hour_beginning'].dt.day_name()
df.head()
# Out:
# C:\Users\wande\AppData\Local\Temp\ipykernel_29664\2784414195.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['hour_beginning'] = pd.to_datetime(df['hour_beginning'])
#        hour_beginning         location  Pedestrians  Towards Manhattan  \
# 0 2019-04-30 00:00:00  Brooklyn Bridge            3                  3
# 1 2019-12-31 22:00:00  Brooklyn Bridge           10                  9
# 2 2019-12-31 23:00:00  Brooklyn Bridge            2                  0
# 3 2019-12-31 21:00:00  Brooklyn Bridge           12                  0
# 4 2019-04-01 03:00:00  Brooklyn Bridge            1                  0
#
#    Towards Brooklyn weather_summary  temperature  precipitation        lat  \
# 0                 0             NaN          NaN            NaN  40.708164
# 1                 1          cloudy         42.0         0.0005  40.708164
# ...

# %%
### Comprobando que esten todos los datos ###

df.loc[df['events'].notnull()]
# Out:
#            hour_beginning         location  Pedestrians  Towards Manhattan  \
# 5     2019-12-25 14:00:00  Brooklyn Bridge         3171               1685
# 65    2019-10-31 00:00:00  Brooklyn Bridge           13                 11
# 76    2019-03-17 23:00:00  Brooklyn Bridge            1                  0
# 78    2019-02-18 16:00:00  Brooklyn Bridge         1439                622
# 89    2019-09-02 01:00:00  Brooklyn Bridge            0                  0
# ...                   ...              ...          ...                ...
# 15962 2018-07-04 16:00:00  Brooklyn Bridge         2726               2726
# 15990 2018-07-04 12:00:00  Brooklyn Bridge         2010               1073
# 15997 2018-06-17 23:00:00  Brooklyn Bridge          353                168
# 16017 2018-06-17 03:00:00  Brooklyn Bridge           16                 11
# 16024 2018-06-17 14:00:00  Brooklyn Bridge         2038                897
#
# ...

# %%
# Datos de inicio y final de hora ###

min_dt = df.hour_beginning.min()
max_dt = df.hour_beginning.max()
print(min_dt)
print(max_dt)
# Out:
# 2017-10-01 00:00:00
# 2019-12-31 23:00:00

# %%
### Datos esperados ###

expected_range = pd.date_range(start = min_dt, end = max_dt, freq='H' )
expected_range
# Out:
# C:\Users\wande\AppData\Local\Temp\ipykernel_29664\1829270725.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   expected_range = pd.date_range(start = min_dt, end = max_dt, freq='H' )
# DatetimeIndex(['2017-10-01 00:00:00', '2017-10-01 01:00:00',
#                '2017-10-01 02:00:00', '2017-10-01 03:00:00',
#                '2017-10-01 04:00:00', '2017-10-01 05:00:00',
#                '2017-10-01 06:00:00', '2017-10-01 07:00:00',
#                '2017-10-01 08:00:00', '2017-10-01 09:00:00',
#                ...
#                '2019-12-31 14:00:00', '2019-12-31 15:00:00',
#                '2019-12-31 16:00:00', '2019-12-31 17:00:00',
#                '2019-12-31 18:00:00', '2019-12-31 19:00:00',
#                '2019-12-31 20:00:00', '2019-12-31 21:00:00',
#                '2019-12-31 22:00:00', '2019-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=19728, freq='h')

# %%
### Datos vacios con el rango de hora esperado ###

missing_hours = expected_range.difference(df['hour_beginning'])
print(missing_hours)
# Out:
# DatetimeIndex(['2018-08-01 00:00:00', '2018-08-01 01:00:00',
#                '2018-08-01 02:00:00', '2018-08-01 03:00:00',
#                '2018-08-01 04:00:00', '2018-08-01 05:00:00',
#                '2018-08-01 06:00:00', '2018-08-01 07:00:00',
#                '2018-08-01 08:00:00', '2018-08-01 09:00:00',
#                ...
#                '2018-12-31 14:00:00', '2018-12-31 15:00:00',
#                '2018-12-31 16:00:00', '2018-12-31 17:00:00',
#                '2018-12-31 18:00:00', '2018-12-31 19:00:00',
#                '2018-12-31 20:00:00', '2018-12-31 21:00:00',
#                '2018-12-31 22:00:00', '2018-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=3672, freq='h')

# %%
### Verificar si una hora aparece mas de una vez ###

df['hour_beginning'].value_counts()
# Out:
# hour_beginning
# 2019-11-03 01:00:00    2
# 2019-04-30 00:00:00    1
# 2017-11-11 02:00:00    1
# 2017-11-02 12:00:00    1
# 2017-12-08 11:00:00    1
#                       ..
# 2019-03-19 14:00:00    1
# 2019-06-25 08:00:00    1
# 2019-06-24 05:00:00    1
# 2019-11-11 14:00:00    1
# 2018-07-23 00:00:00    1
# Name: count, Length: 16056, dtype: int64

# %%
### Encontrando el dia duplicado ###

df.loc[df['hour_beginning']=="2019-11-03 01:00:00"]
# Out:
#           hour_beginning         location  Pedestrians  Towards Manhattan  \
# 701  2019-11-03 01:00:00  Brooklyn Bridge            0                  0
# 3019 2019-11-03 01:00:00  Brooklyn Bridge            1                  0
#
#       Towards Brooklyn weather_summary  temperature  precipitation        lat  \
# 701                  0             NaN          NaN            NaN  40.708164
# 3019                 1     clear-night         44.0            0.0  40.708164
#
#            long                     events  \
# 701  -73.999509  Daylight Saving Time ends
# 3019 -73.999509  Daylight Saving Time ends
#
#                                   Location1  hour  month        date day_name
# 701   (40.7081639691088, -73.9995087014816)     1     11  2019-11-03   Sunday
# 3019  (40.7081639691088, -73.9995087014816)     1     11  2019-11-03   Sunday

# %%
### Restablecer el indice ###

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        hour_beginning         location  Pedestrians  Towards Manhattan  \
# 0 2019-04-30 00:00:00  Brooklyn Bridge            3                  3
# 1 2019-12-31 22:00:00  Brooklyn Bridge           10                  9
# 2 2019-12-31 23:00:00  Brooklyn Bridge            2                  0
# 3 2019-12-31 21:00:00  Brooklyn Bridge           12                  0
# 4 2019-04-01 03:00:00  Brooklyn Bridge            1                  0
#
#    Towards Brooklyn weather_summary  temperature  precipitation        lat  \
# 0                 0             NaN          NaN            NaN  40.708164
# 1                 1          cloudy         42.0         0.0005  40.708164
# 2                 2          cloudy         42.0         0.0004  40.708164
# 3                12          cloudy         42.0         0.0036  40.708164
# 4                 1     clear-night         36.0         0.0000  40.708164
#
#         long events                              Location1  hour  month  \
# ...

# %%
### Restableciendo indice ###

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        hour_beginning         location  Pedestrians  Towards Manhattan  \
# 0 2019-04-30 00:00:00  Brooklyn Bridge            3                  3
# 1 2019-12-31 22:00:00  Brooklyn Bridge           10                  9
# 2 2019-12-31 23:00:00  Brooklyn Bridge            2                  0
# 3 2019-12-31 21:00:00  Brooklyn Bridge           12                  0
# 4 2019-04-01 03:00:00  Brooklyn Bridge            1                  0
#
#    Towards Brooklyn weather_summary  temperature  precipitation        lat  \
# 0                 0             NaN          NaN            NaN  40.708164
# 1                 1          cloudy         42.0         0.0005  40.708164
# 2                 2          cloudy         42.0         0.0004  40.708164
# 3                12          cloudy         42.0         0.0036  40.708164
# 4                 1     clear-night         36.0         0.0000  40.708164
#
#         long events                              Location1  hour  month  \
# ...

# %%
### Ordenando los datos por tiempo ###

df = df.sort_values(by='hour_beginning')
df.head()
# Out:
#            hour_beginning         location  Pedestrians  Towards Manhattan  \
# 8846  2017-10-01 00:00:00  Brooklyn Bridge           44                 30
# 9473  2017-10-01 01:00:00  Brooklyn Bridge           30                 17
# 10098 2017-10-01 02:00:00  Brooklyn Bridge           25                 13
# 10733 2017-10-01 03:00:00  Brooklyn Bridge           20                 11
# 11527 2017-10-01 04:00:00  Brooklyn Bridge           18                 10
#
#        Towards Brooklyn      weather_summary  temperature  precipitation  \
# 8846                 14          clear-night         52.0         0.0001
# 9473                 13  partly-cloudy-night         53.0         0.0002
# 10098                12  partly-cloudy-night         52.0         0.0000
# 10733                 9  partly-cloudy-night         51.0         0.0000
# 11527                 8  partly-cloudy-night         51.0         0.0000
#
# ...

# %%
### Rellenando campos ###

df['temperature'] = df['temperature'].fillna(method="ffill")
df['precipitation'] = df['precipitation'].fillna(method="ffill")
df['weather_summary'] = df['weather_summary'].fillna(method="ffill")
# Out:
# C:\Users\wande\AppData\Local\Temp\ipykernel_29664\2605667544.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['temperature'] = df['temperature'].fillna(method="ffill")
# C:\Users\wande\AppData\Local\Temp\ipykernel_29664\2605667544.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['precipitation'] = df['precipitation'].fillna(method="ffill")
# C:\Users\wande\AppData\Local\Temp\ipykernel_29664\2605667544.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['weather_summary'] = df['weather_summary'].fillna(method="ffill")

# %%
### Ver los campos nuevamente ###

df.isnull().sum()
# Out:
# hour_beginning           0
# location                 0
# Pedestrians              0
# Towards Manhattan        0
# Towards Brooklyn         0
# weather_summary          0
# temperature              0
# precipitation            0
# lat                      0
# long                     0
# events               14933
# Location1                0
# hour                     0
# month                    0
# date                     0
# day_name                 0
# dtype: int64

# %%
### Diagrama de pares ###

sns.pairplot(df,
             vars=['Pedestrians', 'temperature', 'precipitation', 'hour', 'month'],
             diag_kind = 'kde',
             plot_kws={'alpha':0.5, 'size': 0.1})

# %%
############################
### Comienzo de la tarea ###
############################

# %%
### TODO Q1 ###

url = 'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?accessType=DOWNLOAD'
df = pd.read_csv(url)
# Out:
# C:\Users\wande\AppData\Local\Temp\ipykernel_11016\1442581291.py:4: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
### TODO Q2 ###

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11730025 entries, 0 to 11730024
# Data columns (total 15 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   country_region_code                                 object
#  1   country_region                                      object
#  2   sub_region_1                                        object
#  3   sub_region_2                                        object
#  4   metro_area                                          object
#  5   iso_3166_2_code                                     object
#  6   census_fips_code                                    float64
#  7   place_id                                            object
#  8   date                                                object
#  9   retail_and_recreation_percent_change_from_baseline  float64
#  10  grocery_and_pharmacy_percent_change_from_baseline   float64
# ...

# %%
### TODO Q3 ###

df.tail()
# Out:
#          country_region_code country_region       sub_region_1 sub_region_2  \
# 11730020                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730021                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730022                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730023                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730024                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#          metro_area iso_3166_2_code  census_fips_code  \
# 11730020        NaN             NaN               NaN
# 11730021        NaN             NaN               NaN
# 11730022        NaN             NaN               NaN
# 11730023        NaN             NaN               NaN
# 11730024        NaN             NaN               NaN
#
#                              place_id        date  \
# 11730020  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-09-22
# 11730021  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2022-09-26
# ...

# %%
### TODO Q4 ###

df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11730025 entries, 0 to 11730024
# Data columns (total 15 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   country_region_code                                 object
#  1   country_region                                      object
#  2   sub_region_1                                        object
#  3   sub_region_2                                        object
#  4   metro_area                                          object
#  5   iso_3166_2_code                                     object
#  6   census_fips_code                                    float64
#  7   place_id                                            object
#  8   date                                                datetime64[ns]
#  9   retail_and_recreation_percent_change_from_baseline  float64
#  10  grocery_and_pharmacy_percent_change_from_baseline   float64
# ...

# %%
### TODO Q5 ###

df_subset = df.loc[(df["country_region_code"] == "ZW") & (df["sub_region_1"] == "Midlands Province")]
df_subset.tail()
# Out:
#          country_region_code country_region       sub_region_1 sub_region_2  \
# 11730020                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730021                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730022                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730023                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 11730024                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#          metro_area iso_3166_2_code  census_fips_code  \
# 11730020        NaN             NaN               NaN
# 11730021        NaN             NaN               NaN
# 11730022        NaN             NaN               NaN
# 11730023        NaN             NaN               NaN
# 11730024        NaN             NaN               NaN
#
#                              place_id       date  \
# 11730020  ChIJRcIZ3-FJNBkRRsj55IcLpfU 2022-09-22
# 11730021  ChIJRcIZ3-FJNBkRRsj55IcLpfU 2022-09-26
# ...

# %%
### TODO Q6 ###

# En la siguiente celda, escriba código para comprobar si faltan datos en los campos ...percent_change_from_baseline
df_subset = df['retail_and_recreation_percent_change_from_baseline'].isnull().sum()

# Imprimir el número de valores faltantes
print("Número de valores faltantes en el subconjunto de datos:", df_subset)

# Compruebe también si faltan filas de datos
missing_rows = df.isnull().any(axis=1).sum()
print("Número de filas con datos faltantes:", missing_rows)

# ¿Qué intervalo de fechas se representa en estos datos?
date_min = df['date'].min()
date_max = df['date'].max()
print("Fecha mínima en los datos:", date_min)
print("Fecha máxima en los datos:", date_max)

# ¿Todos los días dentro de ese rango están incluidos en los datos?

# Si, puesto que con el date max y min estamos estableciendo el alcance de todos los datos
# Out:
# Número de valores faltantes en el subconjunto de datos: 4466484
# Número de filas con datos faltantes: 11730025
# Fecha mínima en los datos: 2020-02-15 00:00:00
# Fecha máxima en los datos: 2022-10-15 00:00:00

# %%
### TODO Q7 ###

# ¿Están completos los datos o faltan algunos datos relevantes?

# Los datos no estan completos, de hecho podemos ver que hacen falta mucha cantidad de datos solamente en el subconjunto de retail_and_recreation_percent_change_from_baseline

# ¿Por qué algunas ubicaciones solo tienen datos parciales disponibles?

# Pueden haber varias razones para esto, la que se nos comento en clase por ejemplo fue que Estados Unidos decidio privatizar sus datos

# Explique por qué pueden faltar algunos datos para otras regiones

# Los datos pueden ser incompletos por diversas razones, como errores de recopilación, errores de transmisión, o incluso como pudo ser el caso de Estados Unidos, privatizar
# los datos de manera que solo estos tengan acceso total, puede haber un acceso parcial para otras regiones que no permita la lectura completa de datos, de la mano
# la siguiente cita "lo que se puede indicar como Ninguno, NaN o incluso 0 o -1, lo que puede ser engañoso cuando 0 o -1 también son válidos valores para ese campo,
# también puede haber filas que no estén en los datos, que esperamos debe estar en los datos", refleja parcialmente esos inconvenientes.

# Extraido de: https://colab.research.google.com/drive/1urfFkyNEA79pc-IyNe7_dtubupphti5G?usp=sharing#scrollTo=Lcx3SRunklYf (12-3-2024)

# %%
### TODO Q8 ###

# URL de los datos de vacunación de EE. UU.
url_vax = 'https://github.com/owid/covid-19-data/raw/master/public/data/vaccinations/us_state_vaccinations.csv'

# Leer los datos de vacunacion
df_vax = pd.read_csv(url_vax)

# Convertir el campo 'date' en formato datetime
df_vax['date'] = pd.to_datetime(df_vax['date'])

# Definicion del estado
target_state = 'California'

# Obtener el subconjunto de datos de California
df_vax_subset = df_vax[df_vax['location'] == target_state]

# Mostrar informacion
print(df_vax_subset.info())
print(df_vax_subset.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 849 entries, 5094 to 5942
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 849 non-null    datetime64[ns]
#  1   location                             849 non-null    object
#  2   total_vaccinations                   422 non-null    float64
#  3   total_distributed                    422 non-null    float64
#  4   people_vaccinated                    422 non-null    float64
#  5   people_fully_vaccinated_per_hundred  421 non-null    float64
#  6   total_vaccinations_per_hundred       422 non-null    float64
#  7   people_fully_vaccinated              421 non-null    float64
#  8   people_vaccinated_per_hundred        422 non-null    float64
#  9   distributed_per_hundred              422 non-null    float64
#  10  daily_vaccinations_raw               375 non-null    float64
# ...

# %%
### TODO Q9 ###

import matplotlib.pyplot as plt

# Bases plot
fig, axs = plt.subplots(7, 1, figsize=(12, 18), sharex=True)

# Lo que vamos a visualizar
titles = ['Retail and Recreation', 'Grocery and Pharmacy', 'Parks', 'Transit Stations', 'Workplaces', 'Residential', 'COVID-19 Vaccinations']

# Columnas
mobility_columns = ['retail_and_recreation_percent_change_from_baseline', 
                    'grocery_and_pharmacy_percent_change_from_baseline', 
                    'parks_percent_change_from_baseline', 
                    'transit_stations_percent_change_from_baseline', 
                    'workplaces_percent_change_from_baseline', 
                    'residential_percent_change_from_baseline']

# Colores para diferenciar
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown']

# Movilidad en situacion de COVID
for i, col in enumerate(mobility_columns):
    axs[i].plot(df['date'], df[col], color=colors[i])
    axs[i].set_title(titles[i] + ' Change')
    axs[i].set_ylabel('Percent Change')
    axs[i].grid(True)

# Grafico por caso
axs[6].plot(df_vax_subset['date'], df_vax_subset['total_vaccinations'], color='blue')
axs[6].set_title(titles[6])
axs[6].set_ylabel('Total Vaccinations')
axs[6].grid(True)

# Etiqueta
plt.xticks(rotation=45)
axs[6].set_xlabel('Date')

plt.tight_layout()
plt.show()
# Out:
# Text(0.5, 1.0, 'Retail and Recreation Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'Grocery and Pharmacy Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'Parks Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'Transit Stations Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'Workplaces Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'Residential Change')
# Text(0, 0.5, 'Percent Change')
# Text(0.5, 1.0, 'COVID-19 Vaccinations')
# Text(0, 0.5, 'Total Vaccinations')
# (array([18262., 18383., 18506., 18628., 18748., 18871., 18993., 19113.,
#         19236., 19358., 19478.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18748.0, 0, '2021-05'),
#   Text(18871.0, 0, '2021-09'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19113.0, 0, '2022-05'),
#   Text(19236.0, 0, '2022-09'),
#   Text(19358.0, 0, '2023-01'),
# ...

# %%
### TODO Q10 ###

# ¿Los resultados parecen satisfacer el “sentido común”?

# Parecen seguir una conducta adecuada segun el comportamiento de los datos, no veo nigun PIKE que indique algun metrica incoordinada o anomalia, siguen un
# estandar relativamente exponencial.

# ¿Qué tendencias, patrones o anomalías notables en los datos de movilidad probablemente estén relacionadas con los casos de COVID-19, 
# las intervenciones no farmacéuticas, como las órdenes de quedarse en casa o las vacunas?

# Con estas intervenciones deberian de haber patrones de conducta que nos indique comportamientos extraordinarios, en el caso donde tuvimos que estar en casa,
# el comportamiento deberia de indicar esta anomalia reductiva y se ve reflejada como menos en el diagrama.

# ¿Qué tendencias, patrones o anomalías notables en los datos de movilidad probablemente estén relacionadas con otros factores?

# Factores como el clima, o como dias festivos entre otros pueden ser relacionados y consecuentes de reduccion a la hora de metricar la grafica.

# ¿Cree que existen problemas graves asociados con el uso de estos datos para comprender los cambios en la movilidad de los usuarios debido al COVID-19?

# En general estos datos podrian no ser completamente precisos, pueden haber sido manipulados por ultima vez en un periodo grande de tiempo y no ser reflejo
# de la realidad entre otros inconvenientes.
